# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 30

# %%
green_2015_6 = pd.read_csv('./green_2015_6.csv')
green_2015_7 = pd.read_csv('./green_2015_7.csv')

# %%
green_2016_6 = pd.read_csv('./green_2016_6.csv')
green_2016_7 = pd.read_csv('./green_2016_7.csv')

# %%
green_2017 = pd.read_csv('./green_2017.csv')
green_2018 = pd.read_csv('./green_2018.csv')

# %%
green_2015_6.shape
green_2015_6.sample(3)
# Out:
# (98960, 23)
#        level_0              level_1             VendorID lpep_pickup_datetime  \
# 98461        2  2015-06-01 23:43:14  2015-06-01 23:55:09                    N
# 64013        1  2015-04-22 23:13:05  2015-04-22 23:33:23                    N
# 23692        2  2015-02-15 16:14:17  2015-02-15 16:21:19                    N
#
#        Lpep_dropoff_datetime  Store_and_fwd_flag  RateCodeID  \
# 98461                      1          -73.995819   40.690716
# 64013                      1          -73.938004   40.681725
# 23692                      1          -73.917778   40.776073
#
#        Pickup_longitude  Pickup_latitude  Dropoff_longitude  ...  Fare_amount  \
# 98461        -73.958847        40.689022                  1  ...          0.5
# 64013          0.000000         0.000000                  1  ...          0.5
# 23692        -73.918999        40.762192                  2  ...          0.5
#
#        Extra  MTA_tax  Tip_amount  Tolls_amount  Ehail_fee  \
# ...

# %%
green_2015_7.shape
green_2015_7.sample(3)
# Out:
# (93377, 21)
#        vendor_id          pickup_time         dropoff_time  rate_code  \
# 24920          1  2015-08-03 20:40:02  2015-08-03 21:05:30          1
# 59997          2  2015-10-03 17:01:47  2015-10-03 17:24:05          1
# 90380          1  2015-12-29 07:21:48  2015-12-29 07:31:12          1
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 24920        -73.992790        40.688808         -73.978081         40.742455
# 59997        -73.975952        40.693417         -73.965637         40.687141
# 90380        -73.955147        40.820225         -73.971786         40.794334
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 24920                2           4.60         20.5    0.5      0.5
# 59997                1           4.06         14.5    0.0      0.5
# 90380                1           2.80         11.0    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# ...

# %%
green_2016_6.shape
green_2016_6.tail(3)
# Out:
# (90180, 21)
#        VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 90177         2  2016-06-07 22:08:13   2016-06-07 22:20:35                  N
# 90178         2  2016-06-18 10:58:40   2016-06-18 11:01:01                  N
# 90179         2  2016-06-26 11:36:44   2016-06-26 11:54:23                  N
#
#        RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 90177           1        -73.926796        40.826488         -73.949570
# 90178           1        -73.862633        40.749706         -73.861984
# 90179           1        -73.947182        40.674976         -73.987877
#
#        Dropoff_latitude  Passenger_count  ...  Fare_amount  Extra  MTA_tax  \
# 90177         40.796474                5  ...         11.5    0.5      0.5
# 90178         40.744293                1  ...          3.5    0.0      0.5
# 90179         40.663254                1  ...         14.0    0.0      0.5
#
# ...

# %%
green_2016_7.shape
green_2016_7.sample(3)
# Out:
# (73676, 19)
#        level_0              level_1             VendorID lpep_pickup_datetime  \
# 54443        2  2016-11-12 17:12:23  2016-11-12 17:33:54                    N
# 18562        2  2016-08-16 23:08:41  2016-08-16 23:14:44                    N
# 6064         2  2016-07-17 20:11:07  2016-07-17 20:31:58                    N
#
#        lpep_dropoff_datetime  store_and_fwd_flag  RatecodeID  PULocationID  \
# 54443                      1                 236         159             1
# 18562                      1                 255          17             2
# 6064                       1                 260          57             5
#
#        DOLocationID  passenger_count  trip_distance  fare_amount  extra  \
# 54443          4.08             16.5            0.0          0.5    0.0
# 18562          1.92              8.0            0.5          0.5    0.0
# 6064           3.78             16.0            0.5          0.5    0.0
#
# ...

# %%
green_2017.shape
green_2017.sample(3)
# Out:
# (117408, 19)
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 97951         2  2017-10-11 20:47:55   2017-10-11 20:52:08                  N
# 59269         2  2017-06-16 22:00:47   2017-06-16 22:22:15                  N
# 6052          1  2017-01-13 16:43:30   2017-01-13 16:59:47                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 97951           1           260            83                1           0.78
# 59269           1           145           195                1           7.62
# 6052            1           247           116                1           1.60
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 97951          5.0    0.5      0.5         0.0           0.0        NaN
# 59269         23.5    0.5      0.5         0.0           0.0        NaN
# 6052          11.0    1.0      0.5         2.0           0.0        NaN
#
# ...

# %%
green_2018.shape
green_2018.sample(3)
# Out:
# (88073, 19)
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 26653         2  2018-04-12 16:49:25   2018-04-12 17:01:41                  N
# 77474         2  2018-11-20 14:25:21   2018-11-20 15:19:40                  N
# 43701         2  2018-06-08 07:51:17   2018-06-08 08:01:03                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 26653           1            95           135                1           2.13
# 77474           1             7           132                1          14.43
# 43701           1           236           263                1           1.01
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 26653         10.5    1.0      0.5        0.00           0.0        NaN
# 77474         46.0    0.0      0.5        0.00           0.0        NaN
# 43701          8.0    0.0      0.5        1.32           0.0        NaN
#
# ...

# %% [markdown]
# # dealing with 2015

# %%
green_2015_6.shape
green_2015_6.columns
green_2015_6.isnull().sum()
# Out:
# (98960, 23)
# Index(['level_0', 'level_1', 'VendorID', 'lpep_pickup_datetime',
#        'Lpep_dropoff_datetime', 'Store_and_fwd_flag', 'RateCodeID',
#        'Pickup_longitude', 'Pickup_latitude', 'Dropoff_longitude',
#        'Dropoff_latitude', 'Passenger_count', 'Trip_distance', 'Fare_amount',
#        'Extra', 'MTA_tax', 'Tip_amount', 'Tolls_amount', 'Ehail_fee',
#        'improvement_surcharge', 'Total_amount', 'Payment_type', 'Trip_type '],
#       dtype='object')
# level_0                      0
# level_1                      0
# VendorID                     0
# lpep_pickup_datetime         0
# Lpep_dropoff_datetime        0
# Store_and_fwd_flag           0
# RateCodeID                   0
# Pickup_longitude             0
# Pickup_latitude              0
# Dropoff_longitude            0
# Dropoff_latitude             0
# Passenger_count              0
# Trip_distance                0
# Fare_amount                  0
# Extra                        0
# ...

# %%
green_2015_6_columns =['VendorID', 'lpep_pickup_datetime',
       'Lpep_dropoff_datetime', 'Store_and_fwd_flag', 'RateCodeID',
       'Pickup_longitude', 'Pickup_latitude', 'Dropoff_longitude',
       'Dropoff_latitude', 'Passenger_count', 'Trip_distance', 'Fare_amount',
       'Extra', 'MTA_tax', 'Tip_amount', 'Tolls_amount', 'Ehail_fee',
       'improvement_surcharge', 'Total_amount', 'Payment_type', 'Trip_type']

# %%
green_2015_6.drop(columns=['Payment_type','Trip_type '], inplace=True)

# %%
green_2015_6.columns = green_2015_6_columns

# %%
green_2015_6.drop(columns='Store_and_fwd_flag', inplace=True)

# %%
green_2015_6.columns = green_2015_6.columns.str.lower()
green_2015_6.columns
# Out:
# Index(['vendorid', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'ratecodeid', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count',
#        'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'ehail_fee', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type '],
#       dtype='object')

# %%
green_2015_6.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

# %%
green_2015_6.columns
# Out:
# Index(['vendor_id', 'pickup_time', 'dropoff_time', 'rate_code',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'trip_distance', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'ehail_fee',
#        'improvement_surcharge', 'total_amount', 'payment_type', 'trip_type',
#        'pickup_loc', 'dropoff_loc'],
#       dtype='object')

# %%
green_2015_6['pickup_loc']=0
green_2015_6['dropoff_loc']=0

# %%
len(['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc'])
# Out:
# 20

# %%
final_green_2015_6 = green_2015_6[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2015_6.sample(5)
# Out:
#        vendor_id          pickup_time         dropoff_time  passenger_count  \
# 85973          2  2015-06-14 17:06:50  2015-06-14 17:12:19                2
# 93223          2  2015-06-27 03:38:03  2015-06-27 03:41:35                6
# 15517          2  2015-02-15 01:01:46  2015-02-15 01:15:15                1
# 22003          2  2015-02-13 14:46:54  2015-02-13 15:07:48                1
# 73594          2  2015-05-24 01:18:40  2015-05-24 01:23:41                1
#
#        trip_distance  rate_code  payment_type  fare_amount  extra  mta_tax  \
# 85973           0.83          1             2          5.5    0.0      0.5
# 93223           0.78          1             1          5.0    0.5      0.5
# 15517           1.30          1             1         10.5    0.5      0.5
# 22003           2.69          1             2         14.5    0.0      0.5
# 73594           0.82          1             2          5.5    0.5      0.5
#
# ...

# %% [markdown]
# green has extra field trip_type

# %%
final_green_2015_6.isnull().sum()
final_green_2015_6.shape
# Out:
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# rate_code                0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_longitude         0
# pickup_latitude          0
# dropoff_longitude        0
# dropoff_latitude         0
# pickup_loc               0
# dropoff_loc              0
# trip_type                0
# dtype: int64
# (98960, 21)

# %%
green_2015_7.shape
green_2015_7.columns = green_2015_7.columns.str.lower()
# Out:
# (93377, 21)

# %%
green_2015_7.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

# %%
green_2015_7.drop(columns=['ehail_fee','store_and_fwd_flag'], inplace=True)

# %%
green_2015_7.sample(5)
# Out:
#        vendor_id          pickup_time         dropoff_time  rate_code  \
# 33042          1  2015-09-13 04:23:25  2015-09-13 04:49:53          1
# 12289          2  2015-07-06 19:45:59  2015-07-06 19:52:55          1
# 92838          1  2015-12-05 23:46:14  2015-12-06 00:07:14          1
# 6015           2  2015-07-24 17:58:31  2015-07-24 18:01:41          1
# 65757          2  2015-11-14 17:21:17  2015-11-14 17:40:48          1
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 33042        -73.955681        40.719719         -73.980476         40.782215
# 12289        -73.977333        40.683769         -73.960808         40.660744
# 92838        -73.963905        40.718163         -73.992897         40.729847
# 6015         -73.945328        40.807537         -73.935837         40.803898
# 65757        -73.948090        40.830025         -73.983757         40.776283
#
#        passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# ...

# %%
green_2015_7['pickup_loc']=0
green_2015_7['dropoff_loc']=0

# %%
final_green_2015_7 = green_2015_7[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2015_7.shape
green_2015_7.shape
# Out:
# (93377, 21)
# (93377, 21)

# %%
final_green_2015_6.columns==final_green_2015_7.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %% [markdown]
# # dealing with 2016

# %%
green_2016_6.shape
# green_2016_6.columns
green_2016_6.isnull().sum()

green_2016_7.shape
# green_2016_7.columns
green_2016_7.isnull().sum()
# Out:
# (90180, 21)
# VendorID                     0
# lpep_pickup_datetime         0
# Lpep_dropoff_datetime        0
# Store_and_fwd_flag           0
# RateCodeID                   0
# Pickup_longitude             0
# Pickup_latitude              0
# Dropoff_longitude            0
# Dropoff_latitude             0
# Passenger_count              0
# Trip_distance                0
# Fare_amount                  0
# Extra                        0
# MTA_tax                      0
# Tip_amount                   0
# Tolls_amount                 0
# Ehail_fee                90180
# improvement_surcharge        0
# Total_amount                 0
# Payment_type                 0
# Trip_type                    4
# dtype: int64
# (73676, 19)
# level_0                      0
# level_1                      0
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag           0
# RatecodeID                   0
# PULocationID                 0
# ...

# %%
green_2016_7_columns =['VendorID', 'lpep_pickup_datetime',
       'Lpep_dropoff_datetime', 'Store_and_fwd_flag', 'RateCodeID',
       'PULocationID', 'DOLocationID', 'Passenger_count', 'Trip_distance', 'Fare_amount',
       'Extra', 'MTA_tax', 'Tip_amount', 'Tolls_amount', 'Ehail_fee',
       'improvement_surcharge', 'Total_amount', 'Payment_type', 'Trip_type']

# %%
green_2016_7.columns = green_2016_7_columns

# %%
green_2016_7.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

# %%
green_2016_7.columns = green_2016_7.columns.str.lower()

# %%
green_2016_7.drop(columns=['ehail_fee','store_and_fwd_flag'], inplace=True)

# %%
green_2016_7.sample(2)
# Out:
#        vendor_id          pickup_time         dropoff_time  rate_code  \
# 46045          1  2016-10-10 20:11:43  2016-10-10 20:19:21          1
# 27002          2  2016-09-30 12:00:32  2016-09-30 12:08:17          1
#
#        pickup_loc  dropoff_loc  passenger_count  trip_distance  fare_amount  \
# 46045         225          225                1           3.00          6.0
# 27002         255          112                1           1.01          6.5
#
#        extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 46045    0.5      0.5         0.0           0.0                    0.3
# 27002    0.0      0.5         0.0           0.0                    0.3
#
#        total_amount  payment_type  trip_type
# 46045           7.3             3        1.0
# 27002           7.3             2        1.0

# %%
green_2016_7['pickup_longitude'] = 0
green_2016_7['pickup_latitude'] = 0
green_2016_7['dropoff_longitude'] = 0
green_2016_7['dropoff_latitude'] = 0

# %%
green_2016_7.shape
# Out:
# (73676, 21)

# %%
final_green_2016_7 = green_2016_7[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2016_7.sample(3)
# Out:
#        vendor_id          pickup_time         dropoff_time  passenger_count  \
# 22739          2  2016-08-02 06:41:07  2016-08-02 06:58:02                1
# 47042          2  2016-10-24 21:42:34  2016-10-24 21:54:51                1
# 20860          2  2016-08-15 09:12:14  2016-08-15 09:48:42                1
#
#        trip_distance  rate_code  payment_type  fare_amount  extra  mta_tax  \
# 22739           3.03          5             2         15.0    0.0      0.0
# 47042           2.96          1             1         12.0    0.5      0.5
# 20860          10.56          1             1         33.5    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 22739         0.0           0.0                    0.0          15.0
# 47042         2.0           0.0                    0.3          15.3
# 20860         0.0           0.0                    0.3          34.3
#
# ...

# %%
green_2016_6.columns = green_2016_6.columns.str.lower()

# %%
green_2016_6.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

# %%
green_2016_6.drop(columns=['ehail_fee','store_and_fwd_flag'], inplace=True)

# %%
green_2016_6['pickup_loc']=0
green_2016_6['dropoff_loc']=0

# %%
final_green_2016_6 = green_2016_6[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2016_6.sample(3)
# Out:
#        vendor_id          pickup_time         dropoff_time  passenger_count  \
# 49599          2  2016-04-11 23:32:34  2016-04-11 23:49:37                1
# 70932          2  2016-05-04 22:31:58  2016-05-04 22:38:55                1
# 1730           2  2016-01-25 19:15:53  2016-01-25 19:19:14                2
#
#        trip_distance  rate_code  payment_type  fare_amount  extra  mta_tax  \
# 49599           4.08          1             1         15.0    0.5      0.5
# 70932           1.28          1             1          7.0    0.5      0.5
# 1730            0.37          1             1          4.0    1.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 49599        4.08           0.0                    0.3         20.38
# 70932        1.66           0.0                    0.3          9.96
# 1730         1.74           0.0                    0.3          7.54
#
# ...

# %%
final_green_2016_6.trip_type.value_counts()
# Out:
# 1.0    88199
# 2.0     1977
# Name: trip_type, dtype: int64

# %%
final_green_2016_6.fillna(1.0, inplace=True)

# %%
final_green_2016_6.isnull().sum()
# Out:
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# rate_code                0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_longitude         0
# pickup_latitude          0
# dropoff_longitude        0
# dropoff_latitude         0
# pickup_loc               0
# dropoff_loc              0
# trip_type                0
# dtype: int64

# %% [markdown]
# # dealing with 2017

# %%
green_2017.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

green_2017.columns = green_2017.columns.str.lower()

green_2017.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

green_2017.drop(columns=['ehail_fee','store_and_fwd_flag'], inplace=True)

# %%
green_2017.shape
green_2017.isnull().sum()
# Out:
# (117408, 17)
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# rate_code                0
# pickup_loc               0
# dropoff_loc              0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# payment_type             0
# trip_type                0
# dtype: int64

# %%
green_2017['pickup_longitude'] = 0
green_2017['pickup_latitude'] = 0
green_2017['dropoff_longitude'] = 0
green_2017['dropoff_latitude'] = 0

# %%
final_green_2017 = green_2017[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2017.sample(10)
# Out:
#         vendor_id          pickup_time         dropoff_time  passenger_count  \
# 112417          2  2017-12-14 15:58:04  2017-12-14 16:09:51                1
# 75854           2  2017-08-23 09:57:15  2017-08-23 10:04:47                1
# 12174           1  2017-02-24 16:56:25  2017-02-24 17:21:45                2
# 69613           2  2017-07-09 04:37:00  2017-07-09 04:50:29                2
# 116827          1  2017-12-21 10:57:54  2017-12-21 11:08:41                1
# 29583           2  2017-03-31 09:22:18  2017-03-31 09:25:00                1
# 21768           1  2017-03-30 20:10:47  2017-03-30 20:23:23                1
# 100314          2  2017-11-24 20:48:14  2017-11-24 21:00:33                1
# 49112           1  2017-05-09 08:42:38  2017-05-09 09:01:50                1
# 95765           2  2017-10-05 07:45:32  2017-10-05 07:53:55                5
#
#         trip_distance  rate_code  payment_type  fare_amount  extra  mta_tax  \
# ...

# %% [markdown]
# # dealing with 2018

# %%
green_2018.shape
green_2018.isnull().sum()
green_2018.sample(5)
# Out:
# (88073, 19)
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag           0
# RatecodeID                   0
# PULocationID                 0
# DOLocationID                 0
# passenger_count              0
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                88073
# improvement_surcharge        0
# total_amount                 0
# payment_type                 0
# trip_type                    2
# dtype: int64
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 68532         2  2018-10-08 14:35:51   2018-10-08 14:37:59                  N
# 51589         2  2018-07-11 20:06:01   2018-07-11 20:09:57                  N
# 50769         2  2018-07-22 23:40:58   2018-07-22 23:48:27                  N
# ...

# %%
green_2018.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

green_2018.columns = green_2018.columns.str.lower()

green_2018.rename(columns={'vendorid':'vendor_id',
                           'lpep_pickup_datetime':'pickup_time',
                           'lpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'ratecodeid':'rate_code',
                            'trip_type ':'trip_type'}, inplace=True)

green_2018.drop(columns=['ehail_fee','store_and_fwd_flag'], inplace=True)

# %%
green_2018['pickup_longitude'] = 0
green_2018['pickup_latitude'] = 0
green_2018['dropoff_longitude'] = 0
green_2018['dropoff_latitude'] = 0

# %%
final_green_2018 = green_2018[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
       'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
       'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
       'total_amount', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc','trip_type']]

# %%
final_green_2018.columns == final_green_2015_6.columns
final_green_2018.columns == final_green_2015_7.columns
final_green_2018.columns == final_green_2016_6.columns
final_green_2018.columns == final_green_2016_7.columns
final_green_2018.columns == final_green_2017.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
green = pd.concat([final_green_2015_6,final_green_2015_7,final_green_2016_6,final_green_2016_7,final_green_2017,final_green_2018], axis=0, ignore_index=True)

# %%
green.shape
green.isnull().sum()
# Out:
# (561674, 21)
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# rate_code                0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_longitude         0
# pickup_latitude          0
# dropoff_longitude        0
# dropoff_latitude         0
# pickup_loc               0
# dropoff_loc              0
# trip_type                0
# dtype: int64

# %%
green.fillna(1.0, inplace=True)

# %%
green.to_csv('green.csv', index=False)

# %% [markdown]
# Summary of Edits:
# 1. standardized all columns to be same as yellow (one exception)
# 2. ONE EXTRA COLUMN IN GREEN CALLED trip_type
# 3. dropped store_and_fwd_flag column
# 4. dropped ehail_fee column (every value was NaN)
# 5. imputed missing trip_type with mode of 1.0
# 6. no other missing data
