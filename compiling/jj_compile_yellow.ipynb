# %%
import pandas as pd
import numpy as np

# %%
yellow_2015 = pd.read_csv('./yellow_2015.csv')

# %%
yellow_2016_6 = pd.read_csv('./yellow_2016_6.csv')

# %%
yellow_2016_7 = pd.read_csv('./yellow_2016_7.csv')

# %%
yellow_2017 = pd.read_csv('./yellow_2017.csv')

# %%
yellow_2018 = pd.read_csv('./yellow_2018.csv')

# %%
yellow_2015.sample(5)
yellow_2015.shape
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 585395          2  2015-05-30 13:15:01   2015-05-30 13:27:36                6
# 717487          2  2015-06-16 10:41:24   2015-06-16 11:02:41                1
# 954857          1  2015-08-19 08:01:49   2015-08-19 08:08:06                1
# 1279288         2  2015-11-18 08:44:21   2015-11-18 08:48:21                1
# 692379          2  2015-06-27 17:39:04   2015-06-27 17:51:46                1
#
#          trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 585395            1.92        -73.992142        40.749302           1
# 717487            3.15        -73.974541        40.791061           1
# 954857            1.60        -74.006027        40.735020           1
# 1279288           0.54        -74.012611        40.716232           1
# 692379            1.34        -73.965446        40.759499           1
#
# ...

# %%
yellow_2016_6.sample(5)
yellow_2016_6.shape
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 612846         2  2016-06-03 15:12:07   2016-06-03 15:22:06                2
# 180384         1  2016-02-16 18:37:57   2016-02-16 18:44:28                1
# 116228         2  2016-02-06 05:06:25   2016-02-06 05:11:39                1
# 231274         1  2016-03-13 11:51:17   2016-03-13 12:03:30                1
# 67886          2  2016-01-06 01:55:11   2016-01-06 01:57:20                1
#
#         trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 612846           1.10        -73.963631        40.793282           1
# 180384           0.90        -73.984352        40.728855           1
# 116228           1.49        -73.987289        40.692410           1
# 231274           0.90        -73.976868        40.743584           1
# 67886            0.49        -73.980927        40.753277           1
#
#        store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
yellow_2016_7.sample(5)
yellow_2016_7.shape
# Out:
#         level_0              level_1             VendorID  \
# 194234        2  2016-08-25 21:54:16  2016-08-25 22:22:38
# 283057        1  2016-09-06 11:53:13  2016-09-06 12:05:48
# 546052        2  2016-12-28 20:11:57  2016-12-29 20:06:07
# 508299        1  2016-11-23 19:25:17  2016-11-23 20:15:22
# 257689        2  2016-09-19 09:54:05  2016-09-19 10:00:05
#
#         tpep_pickup_datetime  tpep_dropoff_datetime  passenger_count  \
# 194234                     1                   5.08                1
# 283057                     1                   1.60                1
# 546052                     1                   1.59                1
# 508299                     1                  18.40                2
# 257689                     1                   0.58                1
#
#        trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  \
# 194234             N         264                 264             2
# ...

# %%
yellow_2017.sample(5)
yellow_2017.shape
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 248490          1  2017-03-27 10:05:17   2017-03-27 10:13:30                1
# 1030860         2  2017-11-26 01:28:10   2017-11-26 01:42:16                1
# 716133          1  2017-08-26 19:51:47   2017-08-26 19:58:59                1
# 592955          1  2017-07-25 18:48:34   2017-07-25 18:55:18                1
# 194540          1  2017-03-19 00:06:57   2017-03-19 00:07:12                1
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 248490            0.60           1                  N            90
# 1030860           4.16           1                  N           239
# 716133            0.90           1                  N           162
# 592955            1.20           1                  N           143
# 194540            0.00           5                  N           232
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
yellow_2018.sample(5)
yellow_2018.shape
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 872857         2  2018-11-23 17:21:43   2018-11-23 17:41:40                1
# 600107         2  2018-07-09 19:37:43   2018-07-09 20:08:23                1
# 143317         2  2018-02-10 09:37:55   2018-02-10 09:42:27                6
# 344810         1  2018-04-11 21:03:12   2018-04-11 21:14:54                2
# 581602         1  2018-07-09 22:43:07   2018-07-09 22:58:29                1
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 872857           5.25           1                  N            79
# 600107          17.20           2                  N           132
# 143317           1.00           1                  N           237
# 344810           1.60           1                  N            68
# 581602           2.80           1                  N           163
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %% [markdown]
# # dealing with 2015

# %%
yellow_2015.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
yellow_2015.rename(columns={'VendorID':'vendor_id',
                           'tpep_pickup_datetime':'pickup_time',
                           'tpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'RateCodeID':'rate_code'}, inplace=True)

# %%
yellow_2015.columns
yellow_2015.shape
# Out:
# Index(['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
#        'trip_distance', 'pickup_longitude', 'pickup_latitude', 'rate_code',
#        'store_and_fwd_flag', 'dropoff_longitude', 'dropoff_latitude',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount'],
#       dtype='object')
# (1461131, 19)

# %%
yellow_2015.isnull().sum()
# Out:
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# rate_code                0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
#dropping store_and_fwd_flag
final_yellow_2015 = yellow_2015[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count','trip_distance', 'rate_code',           
           'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount','tolls_amount', 'improvement_surcharge', 'total_amount',
             'pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude']]

# %%
final_yellow_2015['pickup_loc']=0
final_yellow_2015['dropoff_loc']=0

# %%
final_yellow_2015.shape
# Out:
# (1461131, 20)

# %% [markdown]
# # dealing with 2016

# %%
yellow_2016_6.shape
yellow_2016_6.columns
yellow_2016_6.isnull().sum()
# Out:
# (694066, 19)
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RatecodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
yellow_2016_6.rename(columns={'VendorID':'vendor_id',
                           'tpep_pickup_datetime':'pickup_time',
                           'tpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'RatecodeID':'rate_code'}, inplace=True)

# %%
#dropping store_and_fwd_flag
final_yellow_2016_6 = yellow_2016_6[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count','trip_distance', 'rate_code',           
           'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount','tolls_amount', 'improvement_surcharge', 'total_amount',
             'pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude']]

# %%
final_yellow_2016_6.shape
# Out:
# (694066, 20)

# %%
final_yellow_2016_6['pickup_loc']=0
final_yellow_2016_6['dropoff_loc']=0

# %%
final_yellow_2016_6.columns==final_yellow_2015.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
yellow_2016_7.shape
yellow_2016_7.columns
yellow_2016_7.isnull().sum()
# Out:
# (617585, 17)
# Index(['level_0', 'level_1', 'VendorID', 'tpep_pickup_datetime',
#        'tpep_dropoff_datetime', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount'],
#       dtype='object')
# level_0                  0
# level_1                  0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# dtype: int64

# %%
yellow_2016_7.sample(5)
# Out:
#         level_0              level_1             VendorID  \
# 597076        2  2016-12-17 14:43:25  2016-12-17 14:54:23
# 547542        2  2016-12-10 14:08:13  2016-12-10 14:58:16
# 535997        1  2016-12-05 15:29:12  2016-12-05 15:38:30
# 577031        2  2016-12-29 02:41:59  2016-12-29 02:45:53
# 444566        2  2016-11-10 13:42:16  2016-11-10 13:49:07
#
#         tpep_pickup_datetime  tpep_dropoff_datetime  passenger_count  \
# 597076                     1                   0.79                1
# 547542                     1                  19.19                2
# 535997                     3                   1.60                1
# 577031                     1                   0.78                1
# 444566                     1                   0.85                1
#
#        trip_distance  RatecodeID  store_and_fwd_flag  PULocationID  \
# 597076             N         237                  43             1
# ...

# %%
yellow_2016_7.columns = ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
       'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
       'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount',
       'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
       'improvement_surcharge', 'total_amount']

# %%
yellow_2016_7.rename(columns={'VendorID':'vendor_id',
                           'tpep_pickup_datetime':'pickup_time',
                           'tpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'RatecodeID':'rate_code'}, inplace=True)

# %%
yellow_2016_7['pickup_longitude']=0
yellow_2016_7['pickup_latitude']=0
yellow_2016_7['dropoff_longitude']=0
yellow_2016_7['dropoff_latitude'] =0

# %%
#dropping store_and_fwd_flag
final_yellow_2016_7 = yellow_2016_7[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count','trip_distance', 'rate_code',           
           'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount','tolls_amount', 'improvement_surcharge', 'total_amount',
             'pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude','pickup_loc','dropoff_loc']]

# %%
final_yellow_2016_7.shape
final_yellow_2016_6.columns==final_yellow_2016_7.columns
# Out:
# (617585, 20)
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# # dealing with 2017

# %%
yellow_2017.shape
yellow_2017.columns
yellow_2017.isnull().sum()
# Out:
# (1134969, 21)
# Index(['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
#        'trip_distance', 'rate_code', 'store_and_fwd_flag', 'pickup_loc',
#        'dropoff_loc', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude'],
#       dtype='object')
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# rate_code                0
# store_and_fwd_flag       0
# pickup_loc               0
# dropoff_loc              0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_longitude         0
# pickup_latitude          0
# ...

# %%
yellow_2017.sample(5)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 695332          2  2017-08-07 21:50:00   2017-08-07 21:52:35                1
# 500807          1  2017-06-28 17:44:54   2017-06-28 18:15:47                1
# 719808          1  2017-08-31 21:24:56   2017-08-31 21:30:18                3
# 322873          1  2017-04-23 22:01:08   2017-04-23 22:29:34                1
# 1042668         2  2017-12-28 10:37:46   2017-12-28 10:47:18                3
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 695332            0.51           1                  N           170
# 500807            9.00           1                  N           164
# 719808            0.90           1                  N            48
# 322873            8.60           1                  N           138
# 1042668           1.16           1                  N           239
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
yellow_2017.rename(columns={'VendorID':'vendor_id',
                           'tpep_pickup_datetime':'pickup_time',
                           'tpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'RatecodeID':'rate_code'}, inplace=True)

# %%
yellow_2017['pickup_longitude']=0
yellow_2017['pickup_latitude']=0
yellow_2017['dropoff_longitude']=0
yellow_2017['dropoff_latitude'] =0

#dropping store_and_fwd_flag
final_yellow_2017 = yellow_2017[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count','trip_distance', 'rate_code',           
           'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount','tolls_amount', 'improvement_surcharge', 'total_amount',
             'pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude','pickup_loc','dropoff_loc']]

# %%
final_yellow_2017.columns==final_yellow_2015.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %% [markdown]
# # dealing with 2018

# %%
yellow_2018.shape
yellow_2018.columns
yellow_2018.isnull().sum()
# Out:
# (1028042, 21)
# Index(['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
#        'trip_distance', 'rate_code', 'store_and_fwd_flag', 'pickup_loc',
#        'dropoff_loc', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude'],
#       dtype='object')
# vendor_id                0
# pickup_time              0
# dropoff_time             0
# passenger_count          0
# trip_distance            0
# rate_code                0
# store_and_fwd_flag       0
# pickup_loc               0
# dropoff_loc              0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# pickup_longitude         0
# pickup_latitude          0
# ...

# %%
yellow_2018.sample(5)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 174868         2  2018-03-12 07:23:34   2018-03-12 07:26:00                2
# 401692         2  2018-05-15 14:23:04   2018-05-15 14:24:51                1
# 585356         2  2018-07-24 21:52:14   2018-07-24 22:09:40                1
# 986830         1  2018-12-07 20:03:15   2018-12-07 20:15:26                1
# 967781         2  2018-12-19 21:19:23   2018-12-19 21:53:25                5
#
#         trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 174868           0.50           1                  N            50
# 401692           0.19           1                  N           142
# 585356           2.27           1                  N           140
# 986830           1.60           1                  N           211
# 967781           8.82           1                  N           138
#
#         DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
yellow_2018.rename(columns={'VendorID':'vendor_id',
                           'tpep_pickup_datetime':'pickup_time',
                           'tpep_dropoff_datetime':'dropoff_time',
                           'PULocationID':'pickup_loc',
                           'DOLocationID':'dropoff_loc',
                           'RatecodeID':'rate_code'}, inplace=True)

# %%
yellow_2018['pickup_longitude']=0
yellow_2018['pickup_latitude']=0
yellow_2018['dropoff_longitude']=0
yellow_2018['dropoff_latitude'] =0

#dropping store_and_fwd_flag
final_yellow_2018 = yellow_2018[['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count','trip_distance', 'rate_code',           
           'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount','tolls_amount', 'improvement_surcharge', 'total_amount',
             'pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude','pickup_loc','dropoff_loc']]

# %%
final_yellow_2018.columns==final_yellow_2015.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
yellow = pd.concat([final_yellow_2015,final_yellow_2016_6,final_yellow_2016_7,final_yellow_2017,final_yellow_2018], axis=0, ignore_index=True)

# %%
yellow.shape
# Out:
# (4935793, 20)

# %%
yellow.sample(5)
# Out:
#          vendor_id          pickup_time         dropoff_time  passenger_count  \
# 1707660          2  2016-03-03 08:13:03  2016-03-03 08:46:29                3
# 3711036          1  2017-10-29 03:53:02  2017-10-29 04:09:43                1
# 4270676          1  2018-05-02 13:39:32  2018-05-02 14:00:56                1
# 4523148          2  2018-07-14 10:48:16  2018-07-14 10:50:31                6
# 213504           1  2015-02-14 10:48:42  2015-02-14 11:02:28                1
#
#          trip_distance  rate_code  payment_type  fare_amount  extra  mta_tax  \
# 1707660           3.99          1             2         23.0    0.0      0.5
# 3711036           4.00          1             1         15.5    0.5      0.5
# 4270676           1.60          1             1         13.5    0.0      0.5
# 4523148           0.47          1             1          4.0    0.0      0.5
# 213504            2.10          1             2         11.0    0.0      0.5
#
# ...

# %%
yellow.columns
# Out:
# Index(['vendor_id', 'pickup_time', 'dropoff_time', 'passenger_count',
#        'trip_distance', 'rate_code', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'pickup_loc', 'dropoff_loc'],
#       dtype='object')

# %%
yellow.to_csv('yellow.csv', index=False)

# %% [markdown]
# Summary of Edits:
# 1. realigned columns in yellow_2016_7
# 2. standardized all the columns for each year (some have pickup/dropoff lat/long and some have zones)
# 3. imputed the missing pickup/dropoff info with 0
# 4. lowercased all column names for consistency
# 4. no other missing data
# 5. dropped store_and_fwd_flag column
